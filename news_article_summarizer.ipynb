# %%
pip install transformers torch sentencepiece
# Out:
# Requirement already satisfied: transformers in .\venv\Lib\site-packages (4.57.1)
# Requirement already satisfied: torch in .\venv\Lib\site-packages (2.14.0)
# Requirement already satisfied: sentencepiece in .\venv\Lib\site-packages (0.2.2)
# Requirement already satisfied: filelock in .\venv\Lib\site-packages (from transformers) (4.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in .\venv\Lib\site-packages (from transformers) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in .\venv\Lib\site-packages (from transformers) (2.5.3)
# Requirement already satisfied: packaging>=20.0 in .\venv\Lib\site-packages (from transformers) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in .\venv\Lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in .\venv\Lib\site-packages (from transformers) (2026.9.10)
# Requirement already satisfied: requests in .\venv\Lib\site-packages (from transformers) (2.34.2)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in .\venv\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in .\venv\Lib\site-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.27 in .\venv\Lib\site-packages (from transformers) (4.70.1)
# Requirement already satisfied: fsspec>=2023.5.0 in .\venv\Lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2026.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in .\venv\Lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in .\venv\Lib\site-packages (from torch) (84.0.0)
# Requirement already satisfied: sympy>=1.13.3 in .\venv\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in .\venv\Lib\site-packages (from torch) (3.7)
# Requirement already satisfied: jinja2 in .\venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\venv\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in .\venv\Lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in .\venv\Lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\venv\Lib\site-packages (from requests->transformers) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\Lib\site-packages (from requests->transformers) (3.20)
# Requirement already satisfied: urllib3<3,>=1.26 in .\venv\Lib\site-packages (from requests->transformers) (2.8.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\venv\Lib\site-packages (from requests->transformers) (2026.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install jupyter ipykernel
# Out:
# Requirement already satisfied: jupyter in .\venv\Lib\site-packages (1.1.1)
# Requirement already satisfied: ipykernel in .\venv\Lib\site-packages (7.3.0)
# Requirement already satisfied: notebook in .\venv\Lib\site-packages (from jupyter) (7.6.3)
# Requirement already satisfied: jupyter-console in .\venv\Lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in .\venv\Lib\site-packages (from jupyter) (7.17.1)
# Requirement already satisfied: ipywidgets in .\venv\Lib\site-packages (from jupyter) (8.1.9)
# Requirement already satisfied: jupyterlab in .\venv\Lib\site-packages (from jupyter) (4.6.4)
# Requirement already satisfied: comm>=0.1.1 in .\venv\Lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in .\venv\Lib\site-packages (from ipykernel) (1.8.22)
# Requirement already satisfied: ipython>=7.23.1 in .\venv\Lib\site-packages (from ipykernel) (9.17.1)
# Requirement already satisfied: jupyter-client>=8.9.0 in .\venv\Lib\site-packages (from ipykernel) (8.10.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in .\venv\Lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in .\venv\Lib\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in .\venv\Lib\site-packages (from ipykernel) (1.7.2)
# Requirement already satisfied: packaging>=22 in .\venv\Lib\site-packages (from ipykernel) (26.3)
# Requirement already satisfied: psutil>=5.7 in .\venv\Lib\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in .\venv\Lib\site-packages (from ipykernel) (27.2.0)
# Requirement already satisfied: tornado>=6.4.1 in .\venv\Lib\site-packages (from ipykernel) (6.5.10)
# Requirement already satisfied: traitlets>=5.4.0 in .\venv\Lib\site-packages (from ipykernel) (5.16.1)
# Requirement already satisfied: colorama>=0.4.4 in .\venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in .\venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.53)
# Requirement already satisfied: pygments>=2.14.0 in .\venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (2.21.0)
# Requirement already satisfied: stack_data>=0.6.0 in .\venv\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in .\venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in .\venv\Lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.13.0 in .\venv\Lib\site-packages (from jupyter-client>=8.9.0->ipykernel) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5 in .\venv\Lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.11.12)
# Requirement already satisfied: six>=1.5 in .\venv\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in .\venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.2)
# Requirement already satisfied: pure-eval in .\venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.4)
# Requirement already satisfied: widgetsnbextension~=4.0.16 in .\venv\Lib\site-packages (from ipywidgets->jupyter) (4.0.16)
# Requirement already satisfied: jupyterlab_widgets~=3.0.17 in .\venv\Lib\site-packages (from ipywidgets->jupyter) (3.0.17)
# Requirement already satisfied: async-lru>=1.0.0 in .\venv\Lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in .\venv\Lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in .\venv\Lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-builder>=1.0.2 in .\venv\Lib\site-packages (from jupyterlab->jupyter) (1.2.3)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in .\venv\Lib\site-packages (from jupyterlab->jupyter) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in .\venv\Lib\site-packages (from jupyterlab->jupyter) (2.21.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in .\venv\Lib\site-packages (from jupyterlab->jupyter) (2.28.1)
# Requirement already satisfied: notebook-shim>=0.2 in .\venv\Lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: anyio in .\venv\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.15.1)
# Requirement already satisfied: certifi in .\venv\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in .\venv\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in .\venv\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.20)
# Requirement already satisfied: h11>=0.16 in .\venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in .\venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in .\venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in .\venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in .\venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (5.11.1)
# Requirement already satisfied: prometheus-client>=0.9 in .\venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.26.0)
# Requirement already satisfied: pywinpty!=3.0.4,>=2.0.1 in .\venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (3.0.5)
# Requirement already satisfied: send2trash>=1.8.2 in .\venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in .\venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in .\venv\Lib\site-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.9.2)
# Requirement already satisfied: babel>=2.10 in .\venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in .\venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in .\venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.26.0)
# Requirement already satisfied: requests>=2.31 in .\venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.34.2)
# Requirement already satisfied: argon2-cffi-bindings in .\venv\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (26.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\venv\Lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2026.6.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in .\venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (4.2.0)
# Requirement already satisfied: pyyaml>=5.3 in .\venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in .\venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in .\venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in .\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in .\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in .\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in .\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in .\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in .\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in .\venv\Lib\site-packages (from nbconvert->jupyter) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in .\venv\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.4.0)
# Requirement already satisfied: defusedxml in .\venv\Lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in .\venv\Lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in .\venv\Lib\site-packages (from nbconvert->jupyter) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in .\venv\Lib\site-packages (from nbconvert->jupyter) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in .\venv\Lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in .\venv\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.6.1)
# Requirement already satisfied: tinycss2>=1.1.0 in .\venv\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in .\venv\Lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2.22.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\venv\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in .\venv\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.8.0)
# Requirement already satisfied: lark>=1.2.2 in .\venv\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=2 in .\venv\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2.1.1)
# Requirement already satisfied: pycparser in .\venv\Lib\site-packages (from cffi>=2->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in .\venv\Lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.9.2)
# Requirement already satisfied: arrow>=0.15.0 in .\venv\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: tzdata in .\venv\Lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter) (2026.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import pipeline

# Load summarization pipeline
summarizer = pipeline(
    "summarization",
    model="sshleifer/distilbart-cnn-12-6"
)

# News article
article = """
NASA scientists have announced the discovery of a new planet
outside our solar system. The planet was detected using advanced
space telescopes and is located hundreds of light-years away from
Earth.

Researchers said that the newly discovered planet has attracted
attention because its size and distance from its star may provide
conditions that could support further scientific investigation.

Scientists are now planning additional observations to study the
planet's atmosphere, temperature and chemical composition. The
research team said that more observations will be required before
they can determine whether the planet could support life.
"""

# Generate summary
summary = summarizer(
    article,
    max_length=100,
    min_length=30,
    do_sample=False
)

# Extract summary text
summary_text = summary[0]["summary_text"]

print("Original Article:")
print(article)

print("\nGenerated Summary:")
print(summary_text)
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# c:\Users\Administrator\venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Administrator\.cache\huggingface\hub\models--sshleifer--distilbart-cnn-12-6. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu
# Original Article:
#
# NASA scientists have announced the discovery of a new planet
# outside our solar system. The planet was detected using advanced
# space telescopes and is located hundreds of light-years away from
# Earth.
#
# Researchers said that the newly discovered planet has attracted
# attention because its size and distance from its star may provide
# conditions that could support further scientific investigation.
#
# Scientists are now planning additional observations to study the
# planet's atmosphere, temperature and chemical composition. The
# research team said that more observations will be required before
# they can determine whether the planet could support life.
#
#
# Generated Summary:
#  The newly discovered planet is located hundreds of light-years away from Earth . Scientists are now planning additional observations to study the planet's atmosphere, temperature and chemical composition .

# %%
def summarize_article(text):
    """
    Generate a summary for a given news article.
    """

    result = summarizer(
        text,
        max_length=100,
        min_length=30,
        do_sample=False
    )

    return result[0]["summary_text"]

# %%
news_article = """
Apple announced a new technology product during an event on Tuesday.
The company said the new product includes improvements in performance,
battery life and artificial intelligence features. The company expects
the product to become available in several countries later this year.
"""

summary = summarize_article(news_article)

print("Summary:")
print(summary)
# Out:
# Your max_length is set to 100, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Summary:
#  The new product includes improvements in performance, battery life and artificial intelligence features . Apple expects the product to become available in several countries later this year .

# %%
original_words = len(article.split())
summary_words = len(summary_text.split())

print("Original words:", original_words)
print("Summary words:", summary_words)

reduction = ((original_words - summary_words) / original_words) * 100

print(f"Text reduction: {reduction:.2f}%")
# Out:
# Original words: 93
# Summary words: 29
# Text reduction: 68.82%

# %%
article = input("Enter your news article:\n")

summary = summarize_article(article)

print("\nGenerated Summary:")
print(summary)
# Out:
# Your max_length is set to 100, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Generated Summary:
#  Text classification is a fundamental task in natural language processing (NLP) that involves assigning predefined categories or labels to text documents . This process enables the automated sorting and organization of textual data, facilitating the extraction of valuable information and insights from large volumes of text . Text classification widely used in various applications, including sentiment analysis, spam detection, topic labelling, and document categorization .
